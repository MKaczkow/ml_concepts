# %%
from torchvision import datasets, transforms
from augmentations import augment_image_sequence
from utils import create_image_sequence, visualize_sequences

# %%
# also, this seems promising:
# https://github.com/okankop/vidaug/blob/1c1ddf2640fe4a9171267d64ae5e3bd70c24d54a/vidaug/augmentors/temporal.py

# %% [markdown]
# # Setup

# %%
transform = transforms.Compose(
    [transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))]
)

# %%
mnist_train = datasets.MNIST(root=".", train=True, download=True, transform=transform)
mnist_test = datasets.MNIST(root=".", train=False, download=True, transform=transform)

# %%
seq_len = 5

# %% [markdown]
# # Demo

# %%
original_sequence = create_image_sequence(mnist_test, seq_len)

# %% [markdown]
# ### Just swap

# %%
p_swap = 1.0
p_revert = 0.0
p_drop = 0.0

# %%
augmented_sequence = augment_image_sequence(
    original_sequence, p_swap=p_swap, p_revert=p_revert, p_drop=p_drop
)

# %%
visualize_sequences(original_sequence, augmented_sequence)

# %% [markdown]
# ### Just revert

# %%
p_swap = 0.0
p_revert = 1.0
p_drop = 0.0

# %%
augmented_sequence = augment_image_sequence(
    original_sequence, p_swap=p_swap, p_revert=p_revert, p_drop=p_drop
)

# %%
visualize_sequences(original_sequence, augmented_sequence)

# %% [markdown]
# ### Just drop

# %%
p_swap = 0.0
p_revert = 0.0
p_drop = 1.0

# %%
augmented_sequence = augment_image_sequence(
    original_sequence, p_swap=p_swap, p_revert=p_revert, p_drop=p_drop
)

# %%
visualize_sequences(original_sequence, augmented_sequence)
